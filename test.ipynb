# %%
import pandas as pd

# %%
df = pd.read_csv("listings.csv")

# %%
df.head(5)
# Out:
#        id                                            name  host_id  host_name  \
# 0   27262    AQA-No7, Great mattress, high speed internet    37177  Emmanouil
# 1   33945        Spacious Cosy aprtm very close to Metro!   146553   Katerina
# 2   49489      Ermou 44 - 3bdr apt in the heart of Athens   225612    Stathis
# 3   60394  Cosy apartment! Great central Athens location!   290864    Dimitra
# 4  133835              Studio in upscale/central location   656936      Elena
#
#    neighbourhood_group           neighbourhood  latitude  longitude  \
# 0                  NaN             ΑΜΠΕΛΟΚΗΠΟΙ  37.98924   23.76500
# 1                  NaN          ΑΓΙΟΣ ΝΙΚΟΛΑΟΣ  38.00673   23.72775
# 2                  NaN  ΕΜΠΟΡΙΚΟ ΤΡΙΓΩΝΟ-ΠΛΑΚΑ  37.97670   23.73064
# 3                  NaN                  ΣΤΑΔΙΟ  37.96738   23.74038
# 4                  NaN                ΚΟΛΩΝΑΚΙ  37.97794   23.74371
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...
